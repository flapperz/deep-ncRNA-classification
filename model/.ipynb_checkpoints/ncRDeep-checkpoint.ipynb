# %% [markdown]
# # Imports

# %%
# !pip install biopython
# Out:
# Requirement already satisfied: biopython in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (1.78)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from biopython) (1.18.1)
# WARNING: You are using pip version 20.0.2; however, version 20.2.4 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/tensorflow_p36/bin/python -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
from Bio import SeqIO
import tensorflow as tf
from tensorflow import keras
print('tf version:',tf.__version__)
print('keras version:',keras.__version__)
# Out:
# tf version: 1.15.3
# keras version: 2.2.4-tf

# %% [markdown]
# # Settings

# %%
test_fasta = 'data/test_13_classes.fasta'
train_fasta = 'data/train.fasta' 
val_fasta = 'data/val.fasta'

# %% [markdown]
# # Preprocess

# %%
w_to_idx = {"<PAD>": 0, "A": 1, "G": 2, "C": 3, "T": 4, "N": 5, "M": 6, "R": 7, "Y": 8, "W": 9,
              "K": 10, "S": 11, "H": 12, "V": 13, "B": 14, "D": 15}
families = [
           '5S_rRNA',
           '5_8S_rRNA',
           'CD-box',
           'HACA-box',
           'IRES',
           'Intron_gpI',
           'Intron_gpII',
           'leader',
           'miRNA',
           'riboswitch',
           'ribozyme',
           'scaRNA',
           'tRNA'
           ]

# %%
# def read_file(fname, mapper=w_to_idx):
    fname = test_fasta
    with open(fname) as fasta_file:  # Will close handle cleanly
        identifiers = []
        lengths = []
        seqs = []
        classes = []
        
        for seq_record in SeqIO.parse(fasta_file, 'fasta'):  # (generator)
            identifiers.append(seq_record.id)
            seqs.append(seq_record.seq)
            classes.append(seq_record.description.split()[1])
            lengths.append(len(seq_record.seq))
            
        df = pd.DataFrame({
            'identifier':identifiers,
            'family':classes,
            'seq':seqs,
            'length':lengths         
            })
        for seq in seqs:
            for w in seq:
                if w not in w_to_idx:
                    print(w)
                
        x_idxs = [[w_to_idx[w] if w in w_to_idx else w for w in seq] for seq in seqs]
# Out:
# W
# R
# S
# Y
# Y
# Y
# Y
# R
# Y
# R
# R
# R
# Y
# R
# Y
# R
# Y
# Y
# R
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# R
# R
# S
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# M
# Y
# D
# R
# R
# M
# K
# W
# W
# K
# S
# M
# K
# N
# N
# N
# N
# D
# N
# Y
# Y
# W
# M
# R
# Y
# K
# S
# W
# S
# W
# K
# R
# W
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# W
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# Y
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# Y
# V
# Y
# R
# W
# M
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# Y
# K
# N
# N
# N
# N
# M
# R
# M
# M
# R
# K
# Y
# Y
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# S
# N
# N
# N
# N
# N
# N
# N
# N
# N
# M
# M
# R
# R
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# W
# Y
# R
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# R
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# N
# W
# N
# N
# Y
# N
# M
# R
# R
# N
# N

# %%
read_file(test_fasta)
# Out:
#                              identifier   family  \
# 0         RF00001_AGFK01083378_1_200-82  5S_rRNA
# 1        RF00001_ABIM01030413_1_269-151  5S_rRNA
# 2             RF00001_FJ968867_1_23-141  5S_rRNA
# 3      RF00001_AFEY01299926_1_3191-3073  5S_rRNA
# 4      RF00001_ACYM01068335_1_1131-1013  5S_rRNA
# ...                                 ...      ...
# 2595  RF02535_ABQO010479098_1_2462-2621     IRES
# 2596  RF02535_ABQO010931335_1_1612-1466     IRES
# 2597     RF02535_ABVD01851849_1_606-739     IRES
# 2598   RF02535_AAGU03005870_1_8100-7981     IRES
# 2599   RF02535_ABRP01282070_1_4603-4725     IRES
#
#                                                     seq  length
# 0     (G, G, A, T, G, C, G, A, T, C, A, T, G, T, C, ...     119
# 1     (G, G, G, T, G, C, G, A, T, C, A, T, A, C, C, ...     119
# 2     (G, C, T, T, A, C, G, G, C, C, A, C, A, C, C, ...     119
# 3     (A, G, C, T, A, C, G, G, C, C, A, T, A, T, C, ...     119
# 4     (G, G, T, T, G, C, G, T, T, C, A, T, A, C, C, ...     119
# ...                                                 ...     ...
# 2595  (A, G, T, G, C, A, A, C, C, G, C, T, G, C, A, ...     160
# 2596  (C, A, G, G, G, C, A, G, T, G, G, C, T, G, C, ...     147
# 2597  (A, G, T, C, C, T, A, A, G, G, C, T, G, C, A, ...     134
# 2598  (G, T, T, T, C, C, A, C, A, G, C, T, G, G, A, ...     120
# 2599  (A, T, T, T, C, C, A, T, T, G, C, T, G, C, A, ...     123
#
# [2600 rows x 4 columns]

# %%
df.family.hist(figsize=(25,5))

# %%
df.head
# Out:
# <bound method NDFrame.head of                              identifier      family  \
# 0      RF00168_ACCK01000036_1_8201-8035  riboswitch
# 1    RF00174_CP000267_1_2890300-2890041  riboswitch
# 2      RF00168_ADGC01003855_1_1616-1451  riboswitch
# 3    RF00167_CP001656_1_1008021-1008121  riboswitch
# 4         RF00174_ABPV01010639_1_234-56  riboswitch
# ..                                  ...         ...
# 645           RF00028_AF430704_1_95-435  Intron_gpI
# 646         RF00028_AF242263_1_863-1238  Intron_gpI
# 647         RF00028_GQ221582_1_709-1190  Intron_gpI
# 648      RF00028_DQ897681_1_52171-52533  Intron_gpI
# 649         RF00028_AY643824_2_679-1086  Intron_gpI
#
#                                                    seq  length
# 0    (T, A, T, A, A, A, G, A, T, A, G, A, G, G, A, ...     167
# 1    (G, G, T, A, G, A, A, T, C, C, A, C, A, G, C, ...     260
# 2    (A, G, A, G, G, T, T, G, C, A, C, G, T, T, T, ...     166
# 3    (A, C, T, A, A, T, T, T, A, A, T, A, A, T, A, ...     101
# 4    (T, T, T, A, C, A, T, C, A, G, A, G, C, A, T, ...     179
# ..                                                 ...     ...
# 645  (C, A, A, G, C, G, G, C, A, T, A, A, A, A, G, ...     341
# 646  (C, T, G, C, G, A, A, A, G, C, A, T, T, T, G, ...     376
# 647  (C, T, A, C, G, G, A, C, T, T, A, A, T, T, G, ...     482
# 648  (C, A, A, C, G, G, A, C, T, T, A, A, T, T, G, ...     363
# 649  (A, C, A, A, A, C, A, A, A, C, A, A, C, G, G, ...     408
#
# [650 rows x 4 columns]>
